# %% [markdown]
# # Joy Ride - Part 3: Parallel Parking
# In this section you will write a function that implements the correct sequence of steps required to parallel park a vehicle.
#
# NOTE: for this segment the vehicle's maximum speed has been set to just over 4 mph. This should make parking a little easier.
#
# ![](https://upload.wikimedia.org/wikipedia/commons/2/26/ParallelParkingAnimation.gif)

# %% [markdown]
# If you have never heard of WASD keys, please check out this [link](https://en.wikipedia.org/wiki/Arrow_keys#WASD_keys).

# %%
# %%HTML
# <link rel="stylesheet" type="text/css" href="buttonStyle.css">
# <button id="launcher">Launch Car Simulator</button>
# <button id="restart">Restart Connection</button>
# <script src="setupLauncher.js"></script>
# <script src="kernelRestart.js"></script>
# Out:
# <link rel="stylesheet" type="text/css" href="buttonStyle.css">
# <button id="launcher">Launch Car Simulator</button>
# <button id="restart">Restart Connection</button>
# <script src="setupLauncher.js"></script>
# <script src="kernelRestart.js"></script>

# %%
# Before running any code changes make sure to click the button "Restart Connection" above first.
# Also make sure to click Reset in the simulator to refresh the connection.
# After making any code changes, make sure to click the button "Restart Connection" above first. Then re-run your code cell (Ctrl+Enter).
# You need to wait for the Kernel Ready message.

car_parameters = {"throttle": 0, "steer": 0, "brake": 0}

def control(pos_x, pos_y, time, velocity):
    """ Controls the simulated car"""
    global car_parameters
    
    
    # TODO: Use WASD keys in simulator to gain an intuitive feel of parallel parking.
    # Pay close attention to the time, position, and velocity in the simulator.
    
    # TODO: Use this information to make decisions about how to set your car parameters
    
    # In this example the car will drive forward for three seconds
    # and then backs up until its pos_y is less than 32 then comes to a stop by braking

    # JDH original
    # if time < 3:
    #    car_parameters['throttle'] = 1
    # elif pos_y > 32:
    #    car_parameters['throttle'] = -1
    # else:
    #    car_parameters['throttle'] = 0
    #    car_parameters['brake'] = 1

    if time < 3.0:
        car_parameters['throttle'] = 0    # let sim settle down
        print ("waiting")
    elif pos_y > 41.0:
        car_parameters['throttle'] = -1
        print ("pos_y: ", pos_y)
        print (">40.0: throttle: ", car_parameters['throttle'])
    elif pos_y > 37.0:
        car_parameters['throttle'] = -1
        car_parameters['steer'] = 1     # turn right?
        print ("pos_y: ", pos_y)
        print (">38.0: throttle: ", car_parameters['throttle'])
        print (">38.0: steer: ", car_parameters['steer'])
    elif pos_y > 34.5:
        car_parameters['throttle'] = -1
        car_parameters['steer'] = 0     # straight back
        print ("pos_y: ", pos_y)
        print (">36.0: throttle: ", car_parameters['throttle'])
        print (">36.0: steer: ", car_parameters['steer'])
    elif pos_y > 31.5:
        car_parameters['throttle'] = -1
        car_parameters['steer'] = -1     # turn left?
        print ("pos_y: ", pos_y)
        print (">32.0: throttle: ", car_parameters['throttle'])
        print (">32.0: steer: ", car_parameters['steer'])
    else:
        print ("pos_y: ", pos_y)
        car_parameters['throttle'] = 0
        car_parameters['steer'] = 0
        car_parameters['brake'] = 1
    
    return car_parameters
    
import src.simulate as sim
sim.run(control)
# Out:
# running
# CONNECTED
# ('172.18.0.1', 49816) connected
# waiting
# waiting
# waiting
# waiting
# waiting
# waiting
# waiting
# waiting
# waiting
# waiting
# waiting
# waiting
# pos_y:  40.70054
# >38.0: throttle:  -1
# >38.0: steer:  1
# pos_y:  40.70054
# >38.0: throttle:  -1
# >38.0: steer:  1
# pos_y:  40.63118
# >38.0: throttle:  -1
# >38.0: steer:  1
# pos_y:  40.42973
# >38.0: throttle:  -1
# >38.0: steer:  1
# pos_y:  40.13567
# >38.0: throttle:  -1
# >38.0: steer:  1
# pos_y:  39.83504
# >38.0: throttle:  -1
# >38.0: steer:  1
# pos_y:  39.57058
# >38.0: throttle:  -1
# >38.0: steer:  1
# pos_y:  39.26736
# >38.0: throttle:  -1
# >38.0: steer:  1
# pos_y:  38.96379
# >38.0: throttle:  -1
# >38.0: steer:  1
# pos_y:  38.62271
# >38.0: throttle:  -1
# >38.0: steer:  1
# pos_y:  38.32071
# >38.0: throttle:  -1
# >38.0: steer:  1
# pos_y:  37.98318
# >38.0: throttle:  -1
# >38.0: steer:  1
# pos_y:  37.6859
# >38.0: throttle:  -1
# >38.0: steer:  1
# pos_y:  37.39193
# >38.0: throttle:  -1
# >38.0: steer:  1
# pos_y:  37.10195
# >38.0: throttle:  -1
# >38.0: steer:  1
# pos_y:  36.85202
# >36.0: throttle:  -1
# >36.0: steer:  0
# pos_y:  36.57132
# >36.0: throttle:  -1
# >36.0: steer:  0
# pos_y:  36.35522
# >36.0: throttle:  -1
# >36.0: steer:  0
# pos_y:  36.1479
# >36.0: throttle:  -1
# >36.0: steer:  0
# pos_y:  35.94079
# >36.0: throttle:  -1
# >36.0: steer:  0
# pos_y:  35.73368
# >36.0: throttle:  -1
# >36.0: steer:  0
# pos_y:  35.52658
# >36.0: throttle:  -1
# >36.0: steer:  0
# pos_y:  35.28988
# >36.0: throttle:  -1
# >36.0: steer:  0
# pos_y:  35.08278
# >36.0: throttle:  -1
# >36.0: steer:  0
# pos_y:  34.84608
# >36.0: throttle:  -1
# >36.0: steer:  0
# pos_y:  34.63897
# >36.0: throttle:  -1
# >36.0: steer:  0
# pos_y:  34.40228
# >32.0: throttle:  -1
# >32.0: steer:  -1
# pos_y:  34.16558
# >32.0: throttle:  -1
# >32.0: steer:  -1
# pos_y:  33.94489
# >32.0: throttle:  -1
# >32.0: steer:  -1
# pos_y:  33.74686
# >32.0: throttle:  -1
# >32.0: steer:  -1
# pos_y:  33.5112
# >32.0: throttle:  -1
# >32.0: steer:  -1
# pos_y:  33.26249
# >32.0: throttle:  -1
# >32.0: steer:  -1
# pos_y:  33.00147
# >32.0: throttle:  -1
# >32.0: steer:  -1
# pos_y:  32.69794
# >32.0: throttle:  -1
# >32.0: steer:  -1
# pos_y:  32.4456
# >32.0: throttle:  -1
# >32.0: steer:  -1
# pos_y:  32.15238
# >32.0: throttle:  -1
# >32.0: steer:  -1
# pos_y:  31.81601
# >32.0: throttle:  -1
# >32.0: steer:  -1
# pos_y:  31.50472
# >32.0: throttle:  -1
# >32.0: steer:  -1
# pos_y:  31.18628
# pos_y:  30.86162
# pos_y:  30.59081
# pos_y:  30.3842
# pos_y:  30.3147
# pos_y:  30.31451
# pos_y:  30.31451
# pos_y:  30.31451
# pos_y:  30.31451
# pos_y:  30.31451
# pos_y:  30.31451
# pos_y:  30.31451
# pos_y:  30.31451
# pos_y:  30.31451
# pos_y:  30.31451
# pos_y:  30.31451
# pos_y:  30.31451
# pos_y:  30.31451
# pos_y:  30.31451
# pos_y:  30.31451
# pos_y:  30.31451
# pos_y:  30.31451
# pos_y:  30.31451
# pos_y:  30.31451
# pos_y:  30.31451
# pos_y:  30.31451
# pos_y:  30.31451
# pos_y:  30.31451
# pos_y:  30.31451
# pos_y:  30.31451
# pos_y:  30.31451
# pos_y:  30.31451
# pos_y:  30.31451
# pos_y:  30.31451
# pos_y:  30.31451
# pos_y:  30.31451
# pos_y:  30.31451
# pos_y:  30.31451
# pos_y:  30.31451
# pos_y:  30.31451
# pos_y:  30.31451
# pos_y:  30.31451
# pos_y:  30.31451
# pos_y:  30.31451
# pos_y:  30.31451
# pos_y:  30.31451
# pos_y:  30.31451
# pos_y:  30.31451
# pos_y:  30.31451
# pos_y:  30.31451
# pos_y:  30.31451
# pos_y:  30.31451
# pos_y:  30.31451
# pos_y:  30.31451
# pos_y:  30.31451
# pos_y:  30.31451
# pos_y:  30.31451
# pos_y:  30.31451
# pos_y:  30.31451
# pos_y:  30.31451
# pos_y:  30.31451
# pos_y:  30.31451
# pos_y:  30.31451
# pos_y:  30.31451
# pos_y:  30.31451
# pos_y:  30.31451
# pos_y:  30.31451
# pos_y:  30.31451
# pos_y:  30.31451
# pos_y:  30.31451
# pos_y:  30.31451
# pos_y:  30.31451
# pos_y:  30.31451
# pos_y:  30.31451
# pos_y:  30.31451
# pos_y:  30.31451
# pos_y:  30.31451
# pos_y:  30.31451
# pos_y:  30.31451
# pos_y:  30.31451
# pos_y:  30.31451
# pos_y:  30.31451
# pos_y:  30.31451
# pos_y:  30.31451
# pos_y:  30.31451
# pos_y:  30.31451
# pos_y:  30.31451
# pos_y:  30.31451
# pos_y:  30.31451
# pos_y:  30.31451
# pos_y:  30.31451
# pos_y:  30.31451
# pos_y:  30.31451
# pos_y:  30.31451
# pos_y:  30.31451
# pos_y:  30.31451
# pos_y:  30.31451
# pos_y:  30.31451
# pos_y:  30.31451
# pos_y:  30.31451
# pos_y:  30.31451
# pos_y:  30.31451
# pos_y:  30.31451
# pos_y:  30.31451
# pos_y:  30.31451
# pos_y:  30.31451
# pos_y:  30.31451
# pos_y:  30.31451
# pos_y:  30.31451
# pos_y:  30.31451
# pos_y:  30.31451
# pos_y:  30.31451
# pos_y:  30.31451
# pos_y:  30.31451
# pos_y:  30.31451
# pos_y:  30.31451
# pos_y:  30.31451
# pos_y:  30.31451
# pos_y:  30.31451
# pos_y:  30.31451
# pos_y:  30.31451
# pos_y:  30.31451
# pos_y:  30.31451
# pos_y:  30.31451
# pos_y:  30.31451
# pos_y:  30.31451
# pos_y:  30.31451
# pos_y:  30.31451
# pos_y:  30.31451
# pos_y:  30.31451
# pos_y:  30.31451
# pos_y:  30.31451
# pos_y:  30.31451
# pos_y:  30.31451
# pos_y:  30.31451
# pos_y:  30.31451
# pos_y:  30.31451
# pos_y:  30.31451
# pos_y:  30.31451
# pos_y:  30.31451
# pos_y:  30.31451
# pos_y:  30.31451
# pos_y:  30.31451
# pos_y:  30.31451
# pos_y:  30.31451
# pos_y:  30.31451
# pos_y:  30.31451
# pos_y:  30.31451
# pos_y:  30.31451
# pos_y:  30.31451
# pos_y:  30.31451
# pos_y:  30.31451
# pos_y:  30.31451
# pos_y:  30.31451
# pos_y:  30.31451
# pos_y:  30.31451
# pos_y:  30.31451
# pos_y:  30.31451
# pos_y:  30.31451
# pos_y:  30.31451
# pos_y:  30.31451
# pos_y:  30.31451
# pos_y:  30.31451
# pos_y:  30.31451
# pos_y:  30.31451
# pos_y:  30.31451
# pos_y:  30.31451
# pos_y:  30.31451
# pos_y:  30.31451
# pos_y:  30.31451
# pos_y:  30.31451
# pos_y:  30.31451
# pos_y:  30.31451
# pos_y:  30.31451
# pos_y:  30.31451
# pos_y:  30.31451
# pos_y:  30.31451
# pos_y:  30.31451
# pos_y:  30.31451
# pos_y:  30.31451
# pos_y:  30.31451
# pos_y:  30.31451
# pos_y:  30.31451
# pos_y:  30.31451
# pos_y:  30.31451
# pos_y:  30.31451
# pos_y:  30.31451
# pos_y:  30.31451
# pos_y:  30.31451
# pos_y:  30.31451
# pos_y:  30.31451
# pos_y:  30.31451
# pos_y:  30.31451
# pos_y:  30.31451
# pos_y:  30.31451
# pos_y:  30.31451
# pos_y:  30.31451
# pos_y:  30.31451
# pos_y:  30.31451
# pos_y:  30.31451
# pos_y:  30.31451
# pos_y:  30.31451
# pos_y:  30.31451
# pos_y:  30.31451
# pos_y:  30.31451
# pos_y:  30.31451
# pos_y:  30.31451
# pos_y:  30.31451
# pos_y:  30.31451
# pos_y:  30.31451
# pos_y:  30.31451
# pos_y:  30.31451
# pos_y:  30.31451
# pos_y:  30.31451
# pos_y:  30.31451
# pos_y:  30.31451
# pos_y:  30.31451
# pos_y:  30.31451
# pos_y:  30.31451
# pos_y:  30.31451
# pos_y:  30.31451
# pos_y:  30.31451
# pos_y:  30.31451
# pos_y:  30.31451
# pos_y:  30.31451
# pos_y:  30.31451
# pos_y:  30.31451
# pos_y:  30.31451
# pos_y:  30.31451
# pos_y:  30.31451
# pos_y:  30.31451
# pos_y:  30.31451
# pos_y:  30.31451
# pos_y:  30.31451
# pos_y:  30.31451
# pos_y:  30.31451
# pos_y:  30.31451
# pos_y:  30.31451
# pos_y:  30.31451
# pos_y:  30.31451
# pos_y:  30.31451
# pos_y:  30.31451
# pos_y:  30.31451

# %% [markdown]
# # Submitting this Project!
# Your parallel park function is "correct" when:
#
# 1. Your car doesn't hit any other cars.
# 2. Your car stops completely inside of the right lane.
#
# Once you've got it working, it's time to submit. Submit by pressing the `SUBMIT` button at the lower right corner of this page.
